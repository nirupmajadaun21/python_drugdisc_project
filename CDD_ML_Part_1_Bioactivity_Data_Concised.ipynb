# %% [markdown]
# # **Bioinformatics Project - Computational Drug Discovery [Part 1] Download Bioactivity Data (Concised version)**
#
# Chanin Nantasenamat
#
# [*'Data Professor' YouTube channel*](http://youtube.com/dataprofessor)
#
# In this Jupyter notebook, we will be building a real-life **data science project** that you can include in your **data science portfolio**. Particularly, we will be building a machine learning model using the ChEMBL bioactivity data.
#
# In **Part 1**, we will be performing Data Collection and Pre-Processing from the ChEMBL Database.
#
# Note for this Concised Version:
# * Redundant code cells were deleted.
# * Code cells for saving files to Google Drive has been deleted.
#
# ---

# %% [markdown]
# ## **ChEMBL Database**
#
# The [*ChEMBL Database*](https://www.ebi.ac.uk/chembl/) is a database that contains curated bioactivity data of more than 2 million compounds. It is compiled from more than 76,000 documents, 1.2 million assays and the data spans 13,000 targets and 1,800 cells and 33,000 indications.
# [Data as of March 25, 2020; ChEMBL version 26].

# %% [markdown]
# ## **Installing libraries**

# %% [markdown]
# Install the ChEMBL web service package so that we can retrieve bioactivity data from the ChEMBL Database.

# %%
! pip install chembl_webresource_client
# Out:
# Collecting chembl_webresource_client
#   Obtaining dependency information for chembl_webresource_client from https://files.pythonhosted.org/packages/c2/7a/81dd5eb6d6166f733c02aeff6eff207ee3cd077872e6a20da925044c3d59/chembl_webresource_client-0.10.9-py3-none-any.whl.metadata
#   Downloading chembl_webresource_client-0.10.9-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: urllib3 in /Users/nirupmasingh/anaconda3/lib/python3.11/site-packages (from chembl_webresource_client) (1.26.15)
# Requirement already satisfied: requests>=2.18.4 in /Users/nirupmasingh/anaconda3/lib/python3.11/site-packages (from chembl_webresource_client) (2.31.0)
# Collecting requests-cache~=1.2 (from chembl_webresource_client)
#   Obtaining dependency information for requests-cache~=1.2 from https://files.pythonhosted.org/packages/cc/23/863f517b5d74e297e669c88093ecd92e13a06c488e90acbd5507819049ac/requests_cache-1.2.0-py3-none-any.whl.metadata
#   Downloading requests_cache-1.2.0-py3-none-any.whl.metadata (9.9 kB)
# Collecting easydict (from chembl_webresource_client)
#   Obtaining dependency information for easydict from https://files.pythonhosted.org/packages/3b/37/9a0c29a3c8ec80c54ff9132160bfc5c6cc6fedda073b391c2a06d9ad0499/easydict-1.12-py3-none-any.whl.metadata
#   Downloading easydict-1.12-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/nirupmasingh/anaconda3/lib/python3.11/site-packages (from requests>=2.18.4->chembl_webresource_client) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/nirupmasingh/anaconda3/lib/python3.11/site-packages (from requests>=2.18.4->chembl_webresource_client) (3.6)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/nirupmasingh/anaconda3/lib/python3.11/site-packages (from requests>=2.18.4->chembl_webresource_client) (2024.2.2)
# Requirement already satisfied: attrs>=21.2 in /Users/nirupmasingh/anaconda3/lib/python3.11/site-packages (from requests-cache~=1.2->chembl_webresource_client) (23.2.0)
# Collecting cattrs>=22.2 (from requests-cache~=1.2->chembl_webresource_client)
#   Obtaining dependency information for cattrs>=22.2 from https://files.pythonhosted.org/packages/b3/0d/cd4a4071c7f38385dc5ba91286723b4d1090b87815db48216212c6c6c30e/cattrs-23.2.3-py3-none-any.whl.metadata
#   Downloading cattrs-23.2.3-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: platformdirs>=2.5 in /Users/nirupmasingh/anaconda3/lib/python3.11/site-packages (from requests-cache~=1.2->chembl_webresource_client) (4.2.0)
# Collecting url-normalize>=1.4 (from requests-cache~=1.2->chembl_webresource_client)
#   Obtaining dependency information for url-normalize>=1.4 from https://files.pythonhosted.org/packages/65/1c/6c6f408be78692fc850006a2b6dea37c2b8592892534e09996e401efc74b/url_normalize-1.4.3-py2.py3-none-any.whl.metadata
#   Downloading url_normalize-1.4.3-py2.py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: six in /Users/nirupmasingh/anaconda3/lib/python3.11/site-packages (from url-normalize>=1.4->requests-cache~=1.2->chembl_webresource_client) (1.16.0)
# Downloading chembl_webresource_client-0.10.9-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 2.1 MB/s eta 0:00:00
# Downloading requests_cache-1.2.0-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 3.9 MB/s eta 0:00:00
# Downloading easydict-1.12-py3-none-any.whl (6.7 kB)
# Downloading cattrs-23.2.3-py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 3.2 MB/s eta 0:00:00
# Downloading url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Installing collected packages: easydict, url-normalize, cattrs, requests-cache, chembl_webresource_client
# Successfully installed cattrs-23.2.3 chembl_webresource_client-0.10.9 easydict-1.12 requests-cache-1.2.0 url-normalize-1.4.3

# %% [markdown]
# ## **Importing libraries**

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## **Search for Target protein**

# %% [markdown]
# ### **Target search for coronavirus**

# %%
# Target search for coronavirus
target = new_client.target
target_query = target.search('HIV')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                     cross_references  \
# 0                                                 []
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4  [{'xref_id': 'P51681', 'xref_name': None, 'xre...
# 5  [{'xref_id': 'P15822', 'xref_name': None, 'xre...
# 6  [{'xref_id': 'Q92993', 'xref_name': None, 'xre...
# 7                                                 []
# 8                                                 []
# 9                                                 []
#
#                        organism  \
# 0  Human immunodeficiency virus
# 1                 HIV-1 M:B_Lai
# 2                  Homo sapiens
# 3                  Homo sapiens
# 4                  Homo sapiens
# 5                  Homo sapiens
# 6                  Homo sapiens
# 7                  Homo sapiens
# 8                  Homo sapiens
# 9                  Homo sapiens
#
#                                            pref_name  score  \
# 0                                       HIV protease   19.0
# 1                                      HIV-1 M:B_Lai   15.0
# 2                        Transcription factor HIVEP2   12.0
# 3                        Ubiquitin thioesterase OTU1   12.0
# 4                      C-C chemokine receptor type 5   11.0
# 5  Human immunodeficiency virus type I enhancer-b...    9.0
# 6                     Histone acetyltransferase KAT5    9.0
# 7                    CCR5/mu opioid receptor complex    9.0
# 8   Zinc finger and BTB domain-containing protein 7A    7.0
# 9                                       80S Ribosome    0.0
#
#    species_group_flag target_chembl_id  \
# 0               False    CHEMBL3638323
# 1               False     CHEMBL612775
# 2               False    CHEMBL4523214
# 3               False    CHEMBL4630833
# 4               False        CHEMBL274
# 5               False       CHEMBL2909
# 6               False       CHEMBL5750
# 7               False    CHEMBL3301384
# 8               False    CHEMBL5069375
# 9               False    CHEMBL3987582
#
#                                    target_components  \
# 0  [{'accession': 'Q9YQ30', 'component_descriptio...
# 1                                                 []
# 2  [{'accession': 'P31629', 'component_descriptio...
# 3  [{'accession': 'Q5VVQ6', 'component_descriptio...
# 4  [{'accession': 'P51681', 'component_descriptio...
# 5  [{'accession': 'P15822', 'component_descriptio...
# 6  [{'accession': 'Q92993', 'component_descriptio...
# 7  [{'accession': 'P51681', 'component_descriptio...
# 8  [{'accession': 'O95365', 'component_descriptio...
# 9  [{'accession': 'P08865', 'component_descriptio...
#
#                     target_type  tax_id
# 0                SINGLE PROTEIN   12721
# 1                      ORGANISM  290579
# 2                SINGLE PROTEIN    9606
# 3                SINGLE PROTEIN    9606
# 4                SINGLE PROTEIN    9606
# 5                SINGLE PROTEIN    9606
# 6                SINGLE PROTEIN    9606
# 7               PROTEIN COMPLEX    9606
# 8                SINGLE PROTEIN    9606
# 9  PROTEIN NUCLEIC-ACID COMPLEX    9606

# %% [markdown]
# ### **Select and retrieve bioactivity data for *HIV virus HIV protease* (first entry)**

# %% [markdown]
# We will assign the fifth entry (which corresponds to the target protein, *coronavirus 3C-like proteinase*) to the ***selected_target*** variable

# %%
selected_target = targets.target_chembl_id[0]
selected_target
# Out:
# 'CHEMBL3638323'

# %% [markdown]
# Here, we will retrieve only bioactivity data for *coronavirus 3C-like proteinase* (CHEMBL3927) that are reported as IC$_{50}$ values in nM (nanomolar) unit.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df.head(6)
df.standard_type.unique()
# Out:
# array(['IC50'], dtype=object)

# %% [markdown]
# Finally we will save the resulting bioactivity data to a CSV file **bioactivity_data.csv**.

# %%
df.to_csv('bioactivity_data_raw.csv', index=False)

# %% [markdown]
# ## **Handling missing data**
# If any compounds has missing value for the **standard_value** column then drop it

# %%
df2 = df[df.standard_value.notna()]
df2.head(3)
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0        None           251760     17634991                  []
# 1        None           251761     17634992                  []
# 2        None           251762     17634993                  []
#
#   assay_chembl_id                                  assay_description  \
# 0   CHEMBL3705170  Enzymatic Assay : This is a fluorometric assay...
# 1   CHEMBL3705170  Enzymatic Assay : This is a fluorometric assay...
# 2   CHEMBL3705170  Enzymatic Assay : This is a fluorometric assay...
#
#   assay_type assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0          B                    None                   None  BAO_0000190  ...
# 1          B                    None                   None  BAO_0000190  ...
# 2          B                    None                   None  BAO_0000190  ...
#
#                 target_organism target_pref_name target_tax_id text_value  \
# 0  Human immunodeficiency virus     HIV protease         12721       None
# 1  Human immunodeficiency virus     HIV protease         12721       None
# 2  Human immunodeficiency virus     HIV protease         12721       None
#
#    toid  type units    uo_units upper_value  value
# 0  None  IC50    nM  UO_0000065        None  0.995
# 1  None  IC50    nM  UO_0000065        None  2.024
# 2  None  IC50    nM  UO_0000065        None  0.599
#
# [3 rows x 46 columns]

# %% [markdown]
# Apparently, for this dataset there is no missing data. But we can use the above code cell for bioactivity data of other target protein.

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# ### **Labeling compounds as either being active, inactive or intermediate**
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be **active** while those greater than 10,000 nM will be considered to be **inactive**. As for those values in between 1,000 and 10,000 nM will be referred to as **intermediate**.

# %%
bioactivity_class = []
for i in df2.standard_value:
  if float(i) >= 10000:
    bioactivity_class.append("inactive")
  elif float(i) <= 1000:
    bioactivity_class.append("active")
  else:
    bioactivity_class.append("intermediate
CC(C)CN([C@H](CO)CCCCNC(=O)[C@H](Cc1ccc2ccccc2...
# 25      CHEMBL3670866  CC(C)CN([C@H](CO)CCCCNC(=O)[C@@H](NS(=O)(=O)c1...
# 26      CHEMBL3670867  CN[C@H](C(=O)NCCCC[C@@H](CO)N(CC(C)C)S(=O)(=O)...
# 27      CHEMBL3670868  CC(C)CN([C@H](CO)CCCCNC(=O)[C@@H](NC(=O)NCC1=C...
# 28      CHEMBL3670869  CC(C)CN([C@H](CO)CCCCNC(=O)[C@@H](NC(=O)NCc1cc...
# 29      CHEMBL3670900  Cc1ccc(C(=O)N[C@@H](Cc2ccccc2C)C(=O)NCCCC[C@@H...
# 30      CHEMBL3670874  COC(=O)N[C@H](C(=O)NCCCCC(C(N)=O)N(CC(C)C)S(=O...
# 31      CHEMBL3670871  COC(=O)N[C@H](C(=O)NCCCC[C@@H](CO)N(Cc1cccnc1)...
# 32      CHEMBL3670880  Cc1ncccc1C(=O)N[C@@H](Cc1ccccc1Br)C(=O)NCCCC[C...
# 33      CHEMBL3670881  Cc1ccc(C(=O)N[C@@H](Cc2ccccc2Br)C(=O)NCCCC[C@@...
# 34      CHEMBL3670878  CC(C)CN([C@H](CO)CCCCNC(=O)[C@@H](Cc1ccccc1Br)...
# 35      CHEMBL3670879  CC(C)CN([C@H](CO)CCCCNC(=O)C(Cc1ccccc1Br)NC(=O...
# 36      CHEMBL3670882  CC(C)CN([C@H](CO)CCCCNC(=O)[C@H](Cc1ccccc1Br)N...
# 37      CHEMBL3670875  CC(C)CN([C@H](CO)CCCCNC(=O)[C@H](Cc1ccccc1Br)N...
# 38      CHEMBL3670876  CC(C)CN([C@H](CO)CCCCNC(=O)[C@@H](Cc1ccccc1Br)...
# 39      CHEMBL3670877  CC(C)CN([C@H](CO)CCCCNC(=O)[C@@H](Cc1ccccc1Br)...
# 40      CHEMBL3670870  COC(=O)N[C@H](C(=O)NCCCC[C@H](C(N)=O)N(CC(C)C)...
# 41      CHEMBL3670870  COC(=O)N[C@H](C(=O)NCCCC[C@H](C(N)=O)N(CC(C)C)...
# 42      CHEMBL3670872  CC(=O)N[C@H](C(=O)NCCCCC(C(N)=O)N(CC(C)C)S(=O)...
# 43      CHEMBL3670873  CC(C)CN(C(CCCCNC(=O)[C@H](CC1=C2C=CC=CC2CC=C1)...
#
#    standard_value
# 0           0.995
# 1           2.024
# 2           0.599
# 3             0.6
# 4            0.29
# 5           1.417
# 6           1.286
# 7           1.353
# 8           4.122
# 9           5.212
# 10          2.876
# 11          3.314
# 12           2.55
# 13           3.81
# 14           2.15
# 15          3.659
# 16          0.899
# 17          0.963
# 18          3.011
# 19          0.503
# 20          0.683
# 21           0.92
# 22           4.95
# 23          0.878
# 24          5.898
# 25          0.601
# 26          0.436
# 27          0.465
# 28           0.51
# 29          0.938
# 30           1.08
# 31          1.007
# 32           0.58
# 33          0.567
# 34          0.336
# 35          0.618
# 36          0.836
# 37          0.471
# 38          0.615
# 39          0.372
# 40          0.652
# 41          0.507
# 42          1.073
# 43           0.58

# %%
bioactivity_class = pd.Series(bioactivity_class, name='bioactivity_class')
df4 = pd.concat([df3, bioactivity_class], axis=1)
df4
# Out:
#    molecule_chembl_id                                   canonical_smiles  \
# 0       CHEMBL3670888  CC(C)CN(Sc1ccc2c(c1)CCO2)[C@H](CO)CCCCNC(=O)[C...
# 1       CHEMBL3670889  CC(C)CN(Sc1ccc2c(c1)OCCO2)[C@H](CO)CCCCNC(=O)[...
# 2       CHEMBL3670890  CC(C)CN([C@H](CO)CCCCNC(=O)[C@H](Cc1ccccc1Br)N...
# 3       CHEMBL3670886  Cc1c(O)cccc1C(=O)N[C@@H](Cc1ccccc1Br)C(=O)NCCC...
# 4       CHEMBL3670887  CC(C)CN([C@H](CO)CCCCNC(=O)[C@H
# 32      CHEMBL3670880  Cc1ncccc1C(=O)N[C@@H](Cc1ccccc1Br)C(=O)NCCCC[C...
# 33      CHEMBL3670881  Cc1ccc(C(=O)N[C@@H](Cc2ccccc2Br)C(=O)NCCCC[C@@...
# 34      CHEMBL3670878  CC(C)CN([C@H](CO)CCCCNC(=O)[C@@H](Cc1ccccc1Br)...
# 35      CHEMBL3670879  CC(C)CN([C@H](CO)CCCCNC(=O)C(Cc1ccccc1Br)NC(=O...
# 36      CHEMBL3670882  CC(C)CN([C@H](CO)CCCCNC(=O)[C@H](Cc1ccccc1Br)N...
# 37      CHEMBL3670875  CC(C)CN([C@H](CO)CCCCNC(=O)[C@H](Cc1ccccc1Br)N...
# 38      CHEMBL3670876  CC(C)CN([C@H](CO)CCCCNC(=O)[C@@H](Cc1ccccc1Br)...
# 39      CHEMBL3670877  CC(C)CN([C@H](CO)CCCCNC(=O)[C@@H](Cc1ccccc1Br)...
# 40      CHEMBL3670870  COC(=O)N[C@H](C(=O)NCCCC[C@H](C(N)=O)N(CC(C)C)...
# 41      CHEMBL3670870  COC(=O)N[C@H](C(=O)NCCCC[C@H](C(N)=O)N(CC(C)C)...
# 42      CHEMBL3670872  CC(=O)N[C@H](C(=O)NCCCCC(C(N)=O)N(CC(C)C)S(=O)...
# 43      CHEMBL3670873  CC(C)CN(C(CCCCNC(=O)[C@H](CC1=C2C=CC=CC2CC=C1)...
#
#    standard_value bioactivity_class
# 0           0.995            active
# 1           2.024            active
# 2           0.599            active
# 3             0.6            active
# 4            0.29            active
# 5           1.417            active
# 6           1.286            active
# 7           1.353            active
# 8           4.122            active
# 9           5.212            active
# 10          2.876            active
# 11          3.314            active
# 12           2.55            active
# 13           3.81            active
# 14           2.15            active
# 15          3.659            active
# 16          0.899            active
# 17          0.963            active
# 18          3.011            active
# 19          0.503            active
# 20          0.683            active
# 21           0.92            active
# 22           4.95            active
# 23          0.878            active
# 24          5.898            active
# 25          0.601            active
# 26          0.436            active
# 27          0.465            active
# 28           0.51            active
# 29          0.938            active
# 30           1.08            active
# 31          1.007            active
# 32           0.58            active
# 33          0.567            active
# 34          0.336            active
# 35          0.618            active
# 36          0.836            active
# 37          0.471            active
# 38          0.615            active
# 39          0.372            active
# 40          0.652            active
# 41          0.507            active
# 42          1.073            active
# 43           0.58            active

# %% [markdown]
# Saves dataframe to CSV file

# %%
df4.to_csv('bioactivity_data_preprocessed.csv', index=False)

# %%
! ls -l
# Out:
# total 240
# -rw-r--r--  1 nirupmasingh  staff  67866 Feb 28 18:03 CDD_ML_Part_1_Bioactivity_Data_Concised.ipynb
# -rw-r--r--  1 nirupmasingh  staff    195 Feb 28 17:49 README.md
# -rw-r--r--@ 1 nirupmasingh  staff   4949 Feb 28 20:47 bioactivity_data_preprocessed.csv
# -rw-r--r--@ 1 nirupmasingh  staff  35258 Feb 28 18:25 bioactivity_data_raw.csv
# drwxr-xr-x  4 nirupmasingh  staff    128 Feb 28 17:41 drugenv
# -rw-r--r--  1 nirupmasingh  staff    162 Feb 28 18:01 script.py

# %% [markdown]
# ---
